# %%
import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.config.run_functions_eagerly(True)
from PIL import Image
import numpy as np
from utils import *
import matplotlib.pyplot as plt
import os, random

# %%
# # Forbidden GPUs
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# set gpus memory used by growth
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
print("find gpus:",gpus)
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# find gpus: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
batch = 10
ind = 3
inh = 180
inw = 390
inc = 3
upscale = 2

# %%
class MySR(tf.keras.models.Model):
    def __init__(self,upscale):
        # 调用父类__init__()方法
        super(MySR, self).__init__()
        self.linear_conv = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation=None, name="linear_conv")
        self.conv2d_1 = tf.keras.layers.Conv2D(3*upscale*upscale, 5, strides=1, padding='same', activation='tanh', name="feature_extraction_1")
        self.conv2d_2 = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation='tanh', name="feature_extraction_2")
        #self.conv2d_3 = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation='tanh', name="feature_extraction_3")
        self.conv2d_4 = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation='tanh', name="motion_wrap1")
        self.conv2d_5 = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation='tanh', name="motion_wrap2")
        self.conv2d_6 = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation='tanh', name="motion_wrap3")
        self.conv2d_7 = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation='tanh', name="motion_wrap4")
        self.conv2d_8 = tf.keras.layers.Conv2D(3*upscale*upscale, 3, strides=1, padding='same', activation='tanh', name="conv1")
        self.conv2d_9 = tf.keras.layers.Conv2D(3, 3, strides=1, padding='same', activation=None, name="conv2")
        self.r = upscale
        self.shuffle = Shuffle(upscale)
        #print("Model inited.")

    def call(self, inputs):
        inputs = inputs/127.5 - 1
        x1,x2,x3 = tf.split(inputs,3,1)
        x1 = tf.squeeze(x1, axis=1)
        x2 = tf.squeeze(x2, axis=1)
        x3 = tf.squeeze(x3, axis=1) # current frame
        # Linear Feature Extraction
        linear_fea = self.linear_conv(x3)
        # Nonlinear Feature Extraction
        x1 = self.conv2d_1(x1)
        x1 = self.conv2d_2(x1)
        #x1 = self.conv2d_3(x1)
        x2 = self.conv2d_1(x2)
        x2 = self.conv2d_2(x2)
        #x2 = self.conv2d_3(x2)
        x3 = self.conv2d_1(x3)
        x3 = self.conv2d_2(x3)
        #x3 = self.conv2d_3(x3)
        # Motion Wrap
        x2 = self.conv2d_4(x2)
        x2 = self.conv2d_5(x2)
        x1 = self.conv2d_6(x1)
        x1 = self.conv2d_7(x1)
        # Feature Concat
        nonlinear_fea = tf.concat([x1,x2,x3],axis=3)
        nonlinear_fea = self.conv2d_8(nonlinear_fea)
        x = nonlinear_fea + linear_fea
        # Pixel Shuffle
        x = self.shuffle(x)
        x = self.conv2d_9(x)
        x = tf.clip_by_value(x, -1, 1)
        x = 127.5*(x+1)
        return x

# %%
mysr = MySR(upscale)
mysr.build(input_shape=(batch,ind,inh,inw,inc))
print(mysr.summary())
# Out:
# Model: "my_sr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# linear_conv (Conv2D)         multiple                  336
# _________________________________________________________________
# feature_extraction_1 (Conv2D multiple                  912
# _________________________________________________________________
# feature_extraction_2 (Conv2D multiple                  1308
# _________________________________________________________________
# motion_wrap1 (Conv2D)        multiple                  1308
# _________________________________________________________________
# motion_wrap2 (Conv2D)        multiple                  1308
# _________________________________________________________________
# motion_wrap3 (Conv2D)        multiple                  1308
# _________________________________________________________________
# motion_wrap4 (Conv2D)        multiple                  1308
# _________________________________________________________________
# conv1 (Conv2D)               multiple                  3900
# _________________________________________________________________
# conv2 (Conv2D)               multiple                  84
# _________________________________________________________________
# shuffle (Shuffle)            multiple                  0
# =================================================================
# Total params: 11,772
# Trainable params: 11,772
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def Huber(y_true, y_pred, delta=0.1, axis=None):
    abs_error = tf.abs(y_pred - y_true)
    quadratic = tf.minimum(abs_error, delta)
    # The following expression is the same in value as
    # tf.maximum(abs_error - delta, 0), but importantly the gradient for the
    # expression when abs_error == delta is 0 (for tf.maximum it would be 1).
    # This is necessary to avoid doubling the gradient, since there is already a
    # nonzero contribution to the gradient from the quadratic term.
    linear = (abs_error - quadratic)
    losses = 0.5 * quadratic**2 + delta * linear
    return tf.reduce_mean(losses, axis=axis)

# %%
mysr.compile(optimizer='adam',
              loss=Huber,
              # loss = 'MAE',
              metrics=['accuracy'])

# %%
def generator(inpath, outpath, batch_size=1, his_num=2):
    # read and sort train data from dir
    x_train_lr_list = os.listdir(inpath)
    x_train_lr_list.sort(key=lambda x:int(x[5:-4]))#倒着数第四位'.'为分界线，按照‘.’左边的数字从小到大排序
    x_train_lr_list = [os.path.join(inpath,c) for c in x_train_lr_list]
    y_train_list = os.listdir(outpath)
    y_train_list.sort(key=lambda x:int(x[5:-4]))
    y_train_list = [os.path.join(outpath,c) for c in y_train_list]
    #i = 0
    while True:
        x_train = []
        y_train = []
        for b in range(batch_size):
            rand = random.randint(3,len(y_train_list)-1)
            lr, hr = loadimgs_from_paths(
                x_train_lr_list[rand-his_num-1:rand], y_train_list[rand-1:rand])
            # print(x_train_lr_list[rand-his_num-1:rand], y_train_list[rand-1:rand])
            x_train.append(lr)
            y_train.append(hr)
        x_train = np.array(x_train)
        y_train = np.squeeze(np.array(y_train),axis=1)
        yield np.float32(x_train), np.float32(y_train)

# %%
history = mysr.fit(generator("../data/540cut","../data/1080cut",batch),steps_per_epoch=10, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 130ms/step - loss: 2.9624 - accuracy: 0.6002
# Epoch 2/200
# 10/10 [==============================] - 1s 130ms/step - loss: 1.7364 - accuracy: 0.6929
# Epoch 3/200
# 10/10 [==============================] - 1s 130ms/step - loss: 1.4061 - accuracy: 0.7309
# Epoch 4/200
# 10/10 [==============================] - 1s 131ms/step - loss: 1.1753 - accuracy: 0.7740
# Epoch 5/200
# 10/10 [==============================] - 1s 132ms/step - loss: 1.0319 - accuracy: 0.7894
# Epoch 6/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.9277 - accuracy: 0.8137
# Epoch 7/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.8255 - accuracy: 0.8453
# Epoch 8/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7735 - accuracy: 0.8485
# Epoch 9/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.7280 - accuracy: 0.8452
# Epoch 10/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.6808 - accuracy: 0.8620
# Epoch 11/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.6363 - accuracy: 0.8640
# Epoch 12/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5981 - accuracy: 0.8685
# Epoch 13/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.5753 - accuracy: 0.8799
# Epoch 14/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.5327 - accuracy: 0.8867
# Epoch 15/200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5125 - accuracy: 0.8886
# Epoch 16/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.4876 - accuracy: 0.8950
# Epoch 17/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.4780 - accuracy: 0.8995
# Epoch 18/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.4512 - accuracy: 0.9076
# Epoch 19/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.4570 - accuracy: 0.9023
# Epoch 20/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.4325 - accuracy: 0.9083
# Epoch 21/200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.4238 - accuracy: 0.9084
# Epoch 22/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.3970 - accuracy: 0.9122
# Epoch 23/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.3971 - accuracy: 0.9119
# Epoch 24/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.3853 - accuracy: 0.9173
# Epoch 25/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.3727 - accuracy: 0.9218
# Epoch 26/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.3695 - accuracy: 0.9212
# Epoch 27/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.3657 - accuracy: 0.9221
# Epoch 28/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.3562 - accuracy: 0.9280
# Epoch 29/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.3389 - accuracy: 0.9319
# Epoch 30/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.3467 - accuracy: 0.9266
# Epoch 31/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.3608 - accuracy: 0.9290
# Epoch 32/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.3600 - accuracy: 0.9291
# Epoch 33/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.3378 - accuracy: 0.9333
# Epoch 34/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.3364 - accuracy: 0.9334
# Epoch 35/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.3248 - accuracy: 0.9366
# Epoch 36/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.3295 - accuracy: 0.9326
# Epoch 37/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.3168 - accuracy: 0.9358
# Epoch 38/200
# 10/10 [==============================] - 1s 139ms/step - loss: 0.3137 - accuracy: 0.9372
# Epoch 39/200
# 10/10 [==============================] - 1s 136ms/step - loss: 0.3110 - accuracy: 0.9391
# Epoch 40/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.3088 - accuracy: 0.9404
# Epoch 41/200
# 10/10 [==============================] - 1s 137ms/step - loss: 0.3047 - accuracy: 0.9370
# Epoch 42/200
# 10/10 [==============================] - 1s 136ms/step - loss: 0.2998 - accuracy: 0.9433
# Epoch 43/200
# 10/10 [==============================] - 1s 137ms/step - loss: 0.2941 - accuracy: 0.9419
# Epoch 44/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.3073 - accuracy: 0.9397
# Epoch 45/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2973 - accuracy: 0.9388
# Epoch 46/200
# 10/10 [==============================] - 1s 134ms/step - loss: 0.2929 - accuracy: 0.9416
# Epoch 47/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2910 - accuracy: 0.9425
# Epoch 48/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2918 - accuracy: 0.9435
# Epoch 49/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2783 - accuracy: 0.9471
# Epoch 50/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2788 - accuracy: 0.9419
# Epoch 51/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2881 - accuracy: 0.9436
# Epoch 52/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2800 - accuracy: 0.9446
# Epoch 53/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2841 - accuracy: 0.9453
# Epoch 54/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2782 - accuracy: 0.9454
# Epoch 55/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2836 - accuracy: 0.9454
# Epoch 56/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2675 - accuracy: 0.9461
# Epoch 57/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2767 - accuracy: 0.9466
# Epoch 58/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2636 - accuracy: 0.9501
# Epoch 59/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2775 - accuracy: 0.9488
# Epoch 60/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2734 - accuracy: 0.9482
# Epoch 61/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2814 - accuracy: 0.9440
# Epoch 62/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2646 - accuracy: 0.9512
# Epoch 63/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2597 - accuracy: 0.9514
# Epoch 64/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2681 - accuracy: 0.9498
# Epoch 65/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2629 - accuracy: 0.9526
# Epoch 66/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2608 - accuracy: 0.9535
# Epoch 67/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2620 - accuracy: 0.9521
# Epoch 68/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2523 - accuracy: 0.9541
# Epoch 69/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2610 - accuracy: 0.9526
# Epoch 70/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2587 - accuracy: 0.9544
# Epoch 71/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2605 - accuracy: 0.9574
# Epoch 72/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2530 - accuracy: 0.9546
# Epoch 73/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2571 - accuracy: 0.9553
# Epoch 74/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2515 - accuracy: 0.9521
# Epoch 75/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2498 - accuracy: 0.9554
# Epoch 76/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2483 - accuracy: 0.9590
# Epoch 77/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2511 - accuracy: 0.9544
# Epoch 78/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2497 - accuracy: 0.9564
# Epoch 79/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2494 - accuracy: 0.9570
# Epoch 80/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2516 - accuracy: 0.9586
# Epoch 81/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2483 - accuracy: 0.9571
# Epoch 82/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2410 - accuracy: 0.9587
# Epoch 83/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2445 - accuracy: 0.9575
# Epoch 84/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2428 - accuracy: 0.9580
# Epoch 85/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2331 - accuracy: 0.9577
# Epoch 86/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2446 - accuracy: 0.9592
# Epoch 87/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2413 - accuracy: 0.9588
# Epoch 88/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2361 - accuracy: 0.9625
# Epoch 89/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2415 - accuracy: 0.9613
# Epoch 90/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2405 - accuracy: 0.9604
# Epoch 91/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2399 - accuracy: 0.9572
# Epoch 92/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2389 - accuracy: 0.9586
# Epoch 93/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2449 - accuracy: 0.9578
# Epoch 94/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2527 - accuracy: 0.9558
# Epoch 95/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2428 - accuracy: 0.9589
# Epoch 96/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2394 - accuracy: 0.9607
# Epoch 97/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2392 - accuracy: 0.9602
# Epoch 98/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2384 - accuracy: 0.9604
# Epoch 99/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2288 - accuracy: 0.9601
# Epoch 100/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2373 - accuracy: 0.9587
# Epoch 101/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2325 - accuracy: 0.9625
# Epoch 102/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2389 - accuracy: 0.9622
# Epoch 103/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2326 - accuracy: 0.9585
# Epoch 104/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2339 - accuracy: 0.9606
# Epoch 105/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2334 - accuracy: 0.9631
# Epoch 106/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2302 - accuracy: 0.9629
# Epoch 107/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2327 - accuracy: 0.9603
# Epoch 108/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2330 - accuracy: 0.9621
# Epoch 109/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2274 - accuracy: 0.9625
# Epoch 110/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2348 - accuracy: 0.9613
# Epoch 111/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2317 - accuracy: 0.9618
# Epoch 112/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2339 - accuracy: 0.9598
# Epoch 113/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2283 - accuracy: 0.9640
# Epoch 114/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2276 - accuracy: 0.9640
# Epoch 115/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2222 - accuracy: 0.9623
# Epoch 116/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2233 - accuracy: 0.9643
# Epoch 117/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2333 - accuracy: 0.9638
# Epoch 118/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2236 - accuracy: 0.9660
# Epoch 119/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2279 - accuracy: 0.9634
# Epoch 120/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2251 - accuracy: 0.9634
# Epoch 121/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2259 - accuracy: 0.9625
# Epoch 122/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2207 - accuracy: 0.9662
# Epoch 123/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2219 - accuracy: 0.9656
# Epoch 124/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2225 - accuracy: 0.9630
# Epoch 125/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2214 - accuracy: 0.9666
# Epoch 126/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2227 - accuracy: 0.9650
# Epoch 127/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2356 - accuracy: 0.9624
# Epoch 128/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2323 - accuracy: 0.9639
# Epoch 129/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2174 - accuracy: 0.9652
# Epoch 130/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2316 - accuracy: 0.9641
# Epoch 131/200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.2268 - accuracy: 0.9638
# Epoch 132/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2145 - accuracy: 0.9674
# Epoch 133/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2249 - accuracy: 0.9647
# Epoch 134/200
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2155 - accuracy: 0.9646
# Epoch 135/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2186 - accuracy: 0.9682
# Epoch 136/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2180 - accuracy: 0.9647
# Epoch 137/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2187 - accuracy: 0.9652
# Epoch 138/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2179 - accuracy: 0.9696
# Epoch 139/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2152 - accuracy: 0.9657
# Epoch 140/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2213 - accuracy: 0.9657
# Epoch 141/200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.2192 - accuracy: 0.9668
# Epoch 142/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2134 - accuracy: 0.9654
# Epoch 143/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2147 - accuracy: 0.9673
# Epoch 144/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2207 - accuracy: 0.9672
# Epoch 145/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2218 - accuracy: 0.9676
# Epoch 146/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2238 - accuracy: 0.9663
# Epoch 147/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2236 - accuracy: 0.9666
# Epoch 148/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2158 - accuracy: 0.9679
# Epoch 149/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2156 - accuracy: 0.9675
# Epoch 150/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2150 - accuracy: 0.9666
# Epoch 151/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2165 - accuracy: 0.9683
# Epoch 152/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2203 - accuracy: 0.9670
# Epoch 153/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2106 - accuracy: 0.9678
# Epoch 154/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2153 - accuracy: 0.9690
# Epoch 155/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2082 - accuracy: 0.9710
# Epoch 156/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2126 - accuracy: 0.9685
# Epoch 157/200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.2168 - accuracy: 0.9676
# Epoch 158/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2139 - accuracy: 0.9683
# Epoch 159/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2160 - accuracy: 0.9699
# Epoch 160/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2124 - accuracy: 0.9660
# Epoch 161/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2198 - accuracy: 0.9624
# Epoch 162/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2311 - accuracy: 0.9616
# Epoch 163/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2249 - accuracy: 0.9641
# Epoch 164/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2120 - accuracy: 0.9674
# Epoch 165/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2088 - accuracy: 0.9689
# Epoch 166/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2055 - accuracy: 0.9691
# Epoch 167/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2140 - accuracy: 0.9706
# Epoch 168/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2116 - accuracy: 0.9702
# Epoch 169/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2117 - accuracy: 0.9693
# Epoch 170/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2118 - accuracy: 0.9674
# Epoch 171/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2253 - accuracy: 0.9647
# Epoch 172/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2225 - accuracy: 0.9686
# Epoch 173/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2133 - accuracy: 0.9680
# Epoch 174/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2131 - accuracy: 0.9680
# Epoch 175/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2130 - accuracy: 0.9687
# Epoch 176/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2100 - accuracy: 0.9706
# Epoch 177/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2076 - accuracy: 0.9720
# Epoch 178/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2008 - accuracy: 0.9719
# Epoch 179/200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.2067 - accuracy: 0.9700
# Epoch 180/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2073 - accuracy: 0.9706
# Epoch 181/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2009 - accuracy: 0.9697
# Epoch 182/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2062 - accuracy: 0.9695
# Epoch 183/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2087 - accuracy: 0.9695
# Epoch 184/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2080 - accuracy: 0.9697
# Epoch 185/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2084 - accuracy: 0.9705
# Epoch 186/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2103 - accuracy: 0.9690
# Epoch 187/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2004 - accuracy: 0.9714
# Epoch 188/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2096 - accuracy: 0.9700
# Epoch 189/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2012 - accuracy: 0.9714
# Epoch 190/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2013 - accuracy: 0.9713
# Epoch 191/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2093 - accuracy: 0.9689
# Epoch 192/200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.2000 - accuracy: 0.9719
# Epoch 193/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2068 - accuracy: 0.9696
# Epoch 194/200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.2101 - accuracy: 0.9695
# Epoch 195/200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2122 - accuracy: 0.9702
# Epoch 196/200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2099 - accuracy: 0.9701
# Epoch 197/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.2099 - accuracy: 0.9716
# Epoch 198/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2083 - accuracy: 0.9714
# Epoch 199/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2048 - accuracy: 0.9716
# Epoch 200/200
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2118 - accuracy: 0.9690

# %%
# Visualization
epochs = 200
l = np.array(history.history['loss'])
a = np.array(history.history['accuracy'])
step = np.linspace(1,epochs,epochs)
plt.plot(step,l,label="Train Loss")
plt.legend(loc='upper right')
plt.title('epoch-loss')
plt.xlim((0, epochs))
plt.gca().set_ylim(bottom=0)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.savefig('./train-loss.png', bbox_inches='tight')
plt.show()
plt.plot(step,a,label="Train Acc")
plt.legend(loc='lower right')
plt.title('epoch-acc')
plt.xlim((0, epochs))
plt.ylim((0., 1))
plt.xlabel('epoch')
plt.ylabel('acc')
plt.savefig('./train-acc.png', bbox_inches='tight')
plt.show()

# %%
mysr.save_weights("./model/Mysr2x")
